# %%
from syndesi import SerialPort

# %%
tmc = SerialPort('/dev/ttyACM0', baudrate=9600)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 tmc = SerialPort('/dev/ttyACM0', baudrate=9600)
#
# File ~/Documents/Projets/Syndesi/Syndesi/syndesi/adapters/serialport.py:112, in SerialPort.__init__(self, port, baudrate, timeout, stop_conditions, alias, rts_cts, event_callback, auto_open)
#     105 self._logger.info(
#     106     f"Setting up SerialPort adapter {self.descriptor}, \
#     107         timeout={timeout} and stop_conditions={self._stop_conditions}"
#     108 )
#     110 self._port: serial.Serial | None = None
# --> 112 self.open()
#     114 self._rts_cts = rts_cts
#
# File ~/Documents/Projets/Syndesi/Syndesi/syndesi/component.py:103, in Component.open(self)
#      99 def open(self) -> None:
#     100     """
#     101     Blocking open communication with the target
#     102     """
# --> 103     _run_sync(self.aopen())
#
# ...
